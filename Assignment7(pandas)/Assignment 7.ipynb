# %%
import pandas as pd

# %% [markdown]
#  Task1=Load and Display Data → Read the dataset and print the first 5 rows.
# -

# %%
data=pd.read_csv("covid_19_country_wise_latest.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
#  Task2=Set the Dataset index is Unnamed: 0
# -

# %%
data.set_index("Unnamed: 0", inplace=True)

# %%
data.head()
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# Unnamed: 0
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
#
#             New deaths  New recovered  Deaths / 100 Cases  \
# Unnamed: 0
# 0                 10.0             18                3.50
# 1                  6.0             63                2.95
# 2                  8.0            749                4.16
# 3                  0.0              0                5.73
# 4                  1.0              0                4.32
#
#             Recovered / 100 Cases  Deaths / 100 Recovered  \
# Unnamed: 0
# 0                           69.49                    5.04
# ...

# %% [markdown]
#  Task3=Now replace the index column Unnamed: 0 name with index
# -

# %%
data.index.rename("index", inplace=True)
data.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# index
# ...

# %% [markdown]
#  Task4=Create Function that take dataset columns and replace whitespace
# with Underscore and update dataset automatically and the pass the
# dataset.
# -

# %%
def clean_column_names(data):
    data.columns = data.columns.str.replace(" ", "_")
    return data

# %%
data = clean_column_names(data)

# %%
data.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
#  Task5:Check Basic Information → Find column names, data types, and
# missing values
# -

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New_cases', 'New_deaths', 'New_recovered', 'Deaths_/_100_Cases',
#        'Recovered_/_100_Cases', 'Deaths_/_100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    object
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New_cases               177 non-null    float64
#  6   New_deaths              177 non-null    float64
#  7   New_recovered           187 non-null    int64
#  8   Deaths_/_100_Cases      187 non-null    float64
#  9   Recovered_/_100_Cases   187 non-null    float64
#  10  Deaths_/_100_Recovered  187 non-null    float64
#  11  Confirmed_last_week     187 non-null    int64
#  12  1_week_change           187 non-null    int64
#  13  1_week_%_increase       187 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region             0
# Confirmed                  0
# Deaths                     0
# Recovered                  0
# Active                     0
# New_cases                 10
# New_deaths                10
# New_recovered              0
# Deaths_/_100_Cases         0
# Recovered_/_100_Cases      0
# Deaths_/_100_Recovered     0
# Confirmed_last_week        0
# 1_week_change              0
# 1_week_%_increase          0
# WHO_Region                 0
# dtype: int64

# %% [markdown]
# Task6:fill the nan values with the mean of the column
# -

# %%
data.fillna(data.mean(numeric_only=True), inplace=True)

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New_cases                 0
# New_deaths                0
# New_recovered             0
# Deaths_/_100_Cases        0
# Recovered_/_100_Cases     0
# Deaths_/_100_Recovered    0
# Confirmed_last_week       0
# 1_week_change             0
# 1_week_%_increase         0
# WHO_Region                0
# dtype: int64

# %% [markdown]
# Task7:Count the number of unique countries in the dataset.
# -

# %%
unique=data["Country/Region"].nunique()

# %%
unique
# Out:
# 187

# %% [markdown]
# Task8:Check if there are any duplicate country entries and remove them if
# needed.
# -

# %%
data.drop_duplicates(subset=["Country/Region"], keep="first", inplace=True)

# %% [markdown]
# Task9:Find the mean, median, and standard deviation of total cases.
# -

# %%
data['total']=data.Confirmed+data.New_cases

# %%
data.total.mean()
# Out:
# np.float64(89413.67594187136)

# %%
data.total.median()
# Out:
# np.float64(6245.0)

# %%
data.total.std()
# Out:
# np.float64(388508.8627176275)

# %% [markdown]
# Task 10:Find out the string in Deaths Column and replace it with the
# mean of Deaths column
# -

# %%
data["Deaths"] = pd.to_numeric(data["Deaths"], errors="coerce")

# %%
mean_deaths = data["Deaths"].mean()

# %%
data.fillna({"Deaths":"mean_deaths"}, inplace=True)

# %%
data.Deaths.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 187 entries, 0 to 186
# Series name: Deaths
# Non-Null Count  Dtype
# --------------  -----
# 187 non-null    object
# dtypes: object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# Task11:Change the datatype of column Deaths
# -

# %%
data.Deaths.dtypes
# Out:
# dtype('O')

# %%
data.Deaths = data.Deaths.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data.Deaths = data.Deaths.astype(int)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
data.Deaths.dtypes

# %% [markdown]
# Task12:Calculate total number of Death and Recovery all over the
# world
# -

# %%
total_deaths=data.Deaths+data.New_deaths

# %%
total_recovered=data.Recovered+data.New_recovered

# %%
total_deaths.sum()

# %%
total_recovered.sum()

# %% [markdown]
# Task13: How many countries have more than 1 million total cases
# -

# %%
data
# Out:
#            Country/Region  Confirmed       Deaths  Recovered  Active  \
# index
# 0             Afghanistan      36263       1269.0      25198    9796
# 1                 Albania       4880        144.0       2745    1991
# 2                 Algeria      27973       1163.0      18837    7973
# 3                 Andorra        907         52.0        803      52
# 4                  Angola        950         41.0        242     667
# ...                   ...        ...          ...        ...     ...
# 182    West Bank and Gaza      10621         78.0       3752    6791
# 183        Western Sahara         10          1.0          8       1
# 184                 Yemen       1691        483.0        833     375
# 185                Zambia       4552        140.0       2815    1597
# 186              Zimbabwe       2704  mean_deaths        542    2126
#
#        New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# index
# ...

# %%
data[data["total"] > 1_000_000].shape[0]
# Out:
# 3

# %% [markdown]
# Task14= Find Countries with Recovery Rate Above 95%
# =

# %%
data["Recovery_Rate"] = (data.Recovered / data.total * 100)

# %%
data[data["Recovery_Rate"] > 95]["Country/Region"].tolist()
# Out:
# ['Brunei',
#  'Dominica',
#  'Grenada',
#  'Holy See',
#  'Iceland',
#  'Malaysia',
#  'Mauritius',
#  'Norway',
#  'Qatar']

# %% [markdown]
# Task15:Drop columns name WHO Region and Confirmed
# -

# %%
data
# Out:
#            Country/Region  Confirmed       Deaths  Recovered  Active  \
# index
# 0             Afghanistan      36263       1269.0      25198    9796
# 1                 Albania       4880        144.0       2745    1991
# 2                 Algeria      27973       1163.0      18837    7973
# 3                 Andorra        907         52.0        803      52
# 4                  Angola        950         41.0        242     667
# ...                   ...        ...          ...        ...     ...
# 182    West Bank and Gaza      10621         78.0       3752    6791
# 183        Western Sahara         10          1.0          8       1
# 184                 Yemen       1691        483.0        833     375
# 185                Zambia       4552        140.0       2815    1597
# 186              Zimbabwe       2704  mean_deaths        542    2126
#
#        New_cases  New_deaths  New_recovered  Deaths_/_100_Cases  \
# index
# ...

# %%
data.drop(columns=["WHO_Region", "Confirmed"], inplace=True)

# %%
data.columns
# Out:
# Index(['Country/Region', 'Deaths', 'Recovered', 'Active', 'New_cases',
#        'New_deaths', 'New_recovered', 'Deaths_/_100_Cases',
#        'Recovered_/_100_Cases', 'Deaths_/_100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase', 'total',
#        'Recovery_Rate'],
#       dtype='object')

# %%
data
# Out:
#            Country/Region       Deaths  Recovered  Active  New_cases  \
# index
# 0             Afghanistan       1269.0      25198    9796      106.0
# 1                 Albania        144.0       2745    1991      117.0
# 2                 Algeria       1163.0      18837    7973      616.0
# 3                 Andorra         52.0        803      52       10.0
# 4                  Angola         41.0        242     667       18.0
# ...                   ...          ...        ...     ...        ...
# 182    West Bank and Gaza         78.0       3752    6791      152.0
# 183        Western Sahara          1.0          8       1        0.0
# 184                 Yemen        483.0        833     375       10.0
# 185                Zambia        140.0       2815    1597       71.0
# 186              Zimbabwe  mean_deaths        542    2126      192.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# ...

# %% [markdown]
# Task16:Find the Country with the Max Deaths
# -

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Convert "Deaths" to numeric, forcing errors to NaN
data["Deaths"] = pd.to_numeric(data["Deaths"], errors="coerce")

# %%
# Fill NaN values with the mean of the column
data["Deaths"].fillna(data["Deaths"].mean(), inplace=True)

# %%
# Convert to integer
data["Deaths"] = data["Deaths"].astype(int)

# %%
data[data["Deaths"] == data["Deaths"].max()]["Country/Region"].values[0]
# Out:
# 'US'

# %% [markdown]
# Task17:Sort Countries by Deaths (Descending Order)
# -

# %%
# Convert "Deaths" column to numeric, forcing errors to NaN
data["Deaths"] = pd.to_numeric(data["Deaths"], errors="coerce")

# %%
# Fill NaN values with the mean of the column
data["Deaths"].fillna(data["Deaths"].mean(), inplace=True)

# %%
# Convert to integer for proper sorting
data["Deaths"] = data["Deaths"].astype(int)

# %%
data.sort_values(by="Deaths", ascending=False)[["Country/Region", "Deaths"]]
# Out:
#                          Country/Region  Deaths
# index
# 173                                  US  148011
# 23                               Brazil   87618
# 177                      United Kingdom   45844
# 111                              Mexico   44022
# 85                                Italy   35112
# ...                                 ...     ...
# 141                         Saint Lucia       0
# 130                    Papua New Guinea       0
# 142    Saint Vincent and the Grenadines       0
# 168                         Timor-Leste       0
# 181                             Vietnam       0
#
# [187 rows x 2 columns]

# %% [markdown]
# Task18:Make new column name Total_cases that have a sum of Deaths,
# Recovered , Active
# -

# %%
data["Total_Cases_Calculated"] = data["Deaths"] + data["Recovered"] + data["Active"]

# %%
data.head()
# Out:
#       Country/Region  Deaths  Recovered  Active  New_cases  New_deaths  \
# index
# 0        Afghanistan    1269      25198    9796      106.0        10.0
# 1            Albania     144       2745    1991      117.0         6.0
# 2            Algeria    1163      18837    7973      616.0         8.0
# 3            Andorra      52        803      52       10.0         0.0
# 4             Angola      41        242     667       18.0         1.0
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0                 18                3.50                  69.49
# 1                 63                2.95                  56.25
# 2                749                4.16                  67.34
# 3                  0                5.73                  88.53
# 4                  0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
# Task19:Calculate Death_Rate for Each Country (Deaths per Total
# Cases) by suing formula (Desths/Total_cases)*100 and save it in
# Dath_Rate column
# -

# %%
data["Death_Rate"] = (data["Deaths"] / data["Total_Cases_Calculated"]) * 100

# %%
data.head()
# Out:
#       Country/Region  Deaths  Recovered  Active  New_cases  New_deaths  \
# index
# 0        Afghanistan    1269      25198    9796      106.0        10.0
# 1            Albania     144       2745    1991      117.0         6.0
# 2            Algeria    1163      18837    7973      616.0         8.0
# 3            Andorra      52        803      52       10.0         0.0
# 4             Angola      41        242     667       18.0         1.0
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0                 18                3.50                  69.49
# 1                 63                2.95                  56.25
# 2                749                4.16                  67.34
# 3                  0                5.73                  88.53
# 4                  0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
# Task20:Identify countries where total cases are increasing but death
# rates remain low.
# -

# %%
low_death_rate_countries= data[(data["Death_Rate"] < 5) & (data["Total_Cases_Calculated"].diff() > 0)]["Country/Region"]

# %%
low_death_rate_countries.values
# Out:
# array(['Algeria', 'Angola', 'Argentina', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Bangladesh', 'Belarus', 'Benin', 'Bolivia', 'Brazil',
#        'Bulgaria', 'Burundi', 'Cabo Verde', 'Cameroon', 'Chile',
#        'Colombia', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Czechia', 'Dominican Republic', 'Estonia',
#        'Eswatini', 'Ethiopia', 'Finland', 'Georgia', 'Germany', 'Grenada',
#        'Guatemala', 'Haiti', 'Honduras', 'India', 'Israel', 'Japan',
#        'Kazakhstan', 'Kuwait', 'Latvia', 'Lebanon', 'Libya', 'Lithuania',
#        'Luxembourg', 'Madagascar', 'Malaysia', 'Mauritania', 'Mongolia',
#        'Montenegro', 'Morocco', 'Namibia', 'Nepal', 'Nicaragua',
#        'Nigeria', 'Oman', 'Pakistan', 'Paraguay', 'Peru', 'Portugal',
#        'Qatar', 'Russia', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Sao Tome and Principe',
#        'Saudi Arabia', 'Serbia', 'Sierra Leone', 'Singapore', 'Somalia',
# ...

# %% [markdown]
# Task 21:print head of only 2 columns Country/Region and Death_Rate
# -

# %%
data[["Country/Region", "Death_Rate"]].head()
# Out:
#       Country/Region  Death_Rate
# index
# 0        Afghanistan    3.499435
# 1            Albania    2.950820
# 2            Algeria    4.157581
# 3            Andorra    5.733186
# 4             Angola    4.315789

# %% [markdown]
# Task22:Create a scatter plot comparing total cases and total deaths.
# -

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data["Total_Cases_Calculated"], data["Deaths"], color='red', alpha=0.5)
plt.title("Total Cases vs Total Deaths")
plt.xlabel("Total Cases")
plt.ylabel("Total Deaths")
plt.show()

# %% [markdown]
# Task23:Save dataset in CSV format
# -

# %%
data.to_csv("cleaned_covid_data.csv", index=False)

# %%
data1=pd.read_csv("cleaned_covid_data.csv")

# %%
data1
# Out:
#          Country/Region  Deaths  Recovered  Active  New_cases  New_deaths  \
# 0           Afghanistan    1269      25198    9796      106.0        10.0
# 1               Albania     144       2745    1991      117.0         6.0
# 2               Algeria    1163      18837    7973      616.0         8.0
# 3               Andorra      52        803      52       10.0         0.0
# 4                Angola      41        242     667       18.0         1.0
# ..                  ...     ...        ...     ...        ...         ...
# 182  West Bank and Gaza      78       3752    6791      152.0         2.0
# 183      Western Sahara       1          8       1        0.0         0.0
# 184               Yemen     483        833     375       10.0         4.0
# 185              Zambia     140       2815    1597       71.0         1.0
# 186            Zimbabwe    3516        542    2126      192.0         2.0
#
#      New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# ...
